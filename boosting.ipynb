# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
df = sns.load_dataset('titanic')
df.dropna(inplace=True)

#X, yを作成
X = df.loc[:, (df.columns!='survived') & (df.columns!='alive')]
y = df['survived']
oe = OrdinalEncoder()
oe.set_output(transform='pandas')
X = oe.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
ada = AdaBoostClassifier(n_estimators=100, learning_rate=0.01, random_state=0).fit(X_train, y_train)
y_pred_ada = ada.predict_proba(X_test)
print(f"adaboost AUC: {roc_auc_score(y_test, y_pred_ada[:, 1])}")
# Out:
# adaboost AUC: 0.9375

# %%
ada.feature_importances_
plt.barh(X.columns, ada.feature_importances_)
# Out:
# <BarContainer object of 13 artists>

# %%
from sklearn.tree import DicisionTreeRegressor
class MyGradientBoostingRegressor:
    def __init__(self, learning_rate = 0.03, n_estimators=100, max_depth=1, random_state=0):
        self.learning_rate = learning_rate
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        self.random_state = random_state
        self.estimators = []
    
    def fit(self, X, y):
        F0 = y.mean()
        Fb = F0
        
        for _ in range(self.n_estimators):
            #残差を計算
            r = y - Fb
            DicisionTreeRegressor(max_depth=)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
from sklearn.tree import DecisionTreeRegressor

# %%
x_train = np.linspace(0, np.pi * 2, num=80) #0から2πまで、80個の等差数列
y_train = np.sin(x_train).reshape(-1, 1)
X_train = x_train.reshape(-1, 1)

x_test = np.linspace(0, np.pi * 2, num=1000).reshape(-1, 1)
X_test = x_test.reshape(-1, 1)

depths = [1, 2, 3, 4, 6, 10]

fig, axs = plt.subplots(2, 3, figsize=(12, 6))
fig.subplots_adjust(hspace=0.3)
ax_1d = axs.reshape(-1)

ax_1d.scatter(x_train, y_train, s=10, ec='gray', fc="coral")
treereg = DecisionTreeRegressor(max_depth=3).fit(X_train, y_train)
y_pred = treereg.predict(X_test)
ax_1d.plot(x_test, y_pred, c='blue', linewidth=1)
ax_1d.set_title("max_depth={}".format(depth))


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_52/2588730399.py in <module>
#      12 ax_1d = axs.reshape(-1)
#      13
# ---> 14 ax_1d.scatter(x_train, y_train, s=10, ec='gray', fc="coral")
#      15 treereg = DecisionTreeRegressor(max_depth=3).fit(X_train, y_train)
#      16 y_pred = treereg.predict(X_test)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'scatter'

# %%
len(x_train)
# Out:
# 80

# %%
for ax, depth in zip(ax_1d, depths):
    ax.scatter(x_train, y_train, s=10, ec='gray', fc="coral")
    treereg = DecisionTreeRegressor(max_depth=depth).fit(X_train, y_train)
    y_pred = treereg.predict(X_test)
    ax.plot(x_test, y_pred, c='blue', linewidth=1)
    ax.set_title("max_depth={}".format(depth)
    
plt.show()
# Out:
#   File "/tmp/ipykernel_28/1654022867.py", line 8
#     plt.show()
#     ^
# SyntaxError: invalid syntax
